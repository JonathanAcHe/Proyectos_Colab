# %% [markdown]
# Conectar Con Google Drive

# %% [markdown]
# https://www.youtube.com/watch?v=9s_JxZv0dvg&ab_channel=ArlesAgustinTaboadaSanchez

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.image as img
import matplotlib.pyplot as plot

#cargarimagendebienvenida
imagen_welcome = img.imread("/content/drive/MyDrive/Archivos_ejemplos/escher.jpg")

#Mostrar imagen
plot.imshow(imagen_welcome)
plot.show()
